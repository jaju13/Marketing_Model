# %%
import pandas as pd
from functools import reduce

# %%
results_folder_path = './predicted_results/'

Revenue = pd.read_csv(results_folder_path+'Predicted_Revenue.csv',index_col=0)
Propensity_CC = pd.read_csv(results_folder_path+'Propensity_Sale_CC.csv',index_col=0)
Propensity_CL = pd.read_csv(results_folder_path+'Propensity_Sale_CL.csv',index_col=0)
Propensity_MF = pd.read_csv(results_folder_path+'Propensity_Sale_MF.csv',index_col=0)

# %%
display(Revenue.head())
display(Propensity_CC.head())
display(Propensity_CL.head())
display(Propensity_MF.head())
# Out:
#    Client  ActBal_CC  TransactionsDeb  TransactionsCred  Count_MF  Sex_F  \
# 0    1217  -0.190496        -0.946779         -0.727636 -0.173651      0
# 1    1038  -0.190496        -1.010282         -0.727636 -0.173651      0
# 2    1219  -0.190496        -0.184737         -0.566048 -0.173651      0
# 3     461  -0.190496         0.132780         -0.081284 -0.173651      1
# 4    1048  -0.190496        -0.819772         -0.566048 -0.173651      1
#
#    VolumeDeb_CA  ActBal_MF  TransactionsDebCashless_Card  VolumeCred_CA  \
# 0     -0.108203  -0.216118                     -0.676363      -0.899303
# 1     -0.973017  -0.216118                     -0.676363      -0.899299
# 2     -0.526868  -0.216118                     -0.287513      -0.525633
# 3      0.952782  -0.216118                     -0.287513       0.675547
# 4     -0.317704  -0.216118                     -0.676363      -0.114703
#
#    VolumeDeb_PaymentOrder  ActBal_CL  VolumeCred  Sex_M  TransactionsDeb_CA  \
# 0                0.929591  -0.221113   -0.870508      1           -1.018349
# 1               -0.700439  -0.221113   -0.870505      1           -1.099640
# 2               -0.138323  -0.221113   -0.543142      1           -0.042862
# 3                0.942550  -0.221113    0.509302      0            0.363591
# 4               -0.700439  -0.221113   -0.183133      0           -0.855768
#
#    VolumeDeb  Predicted_revenue
# 0  -0.190698          11.283205
# 1  -0.895385          11.667446
# 2  -0.531844          11.169191
# 3   0.673837          12.039372
# 4  -0.361409          12.568632
#    Client       Age    Tenure  Count_CA  Count_SA  Count_MF  Count_OVD  \
# 0    1217 -0.182683  0.845548 -0.250376 -0.470764 -0.179349  -0.607332
# 1    1038 -0.676075 -0.037086 -0.250376 -0.470764 -0.179349  -0.607332
# 2    1219 -0.456790 -1.338597 -0.250376 -0.470764 -0.179349  -0.607332
# 3     461 -1.333931 -0.665402 -0.250376  1.519554 -0.179349  -0.607332
# 4    1048  1.297493 -0.560683 -0.250376 -0.470764 -0.179349   1.646545
#
#    Count_CC  Count_CL  ActBal_CA  ...  VolumeDebCashless_Card  \
# 0  -0.33665 -0.296246   2.890179  ...               -0.618694
# 1  -0.33665 -0.296246  -0.629706  ...               -0.618694
# 2  -0.33665 -0.296246   2.059021  ...               -0.520051
# 3  -0.33665 -0.296246  -0.640434  ...                1.090015
# 4  -0.33665 -0.296246   0.356593  ...               -0.618694
#
#    VolumeDeb_PaymentOrder  TransactionsDeb  TransactionsDebCash_Card  \
# 0                0.944452        -0.940391                 -0.714790
# 1               -0.701094        -1.003284                 -0.714790
# 2               -0.133628        -0.185668                 -0.082367
# 3                0.957534         0.128800                 -0.714790
# 4               -0.701094        -0.814604                 -0.398578
#
#    TransactionsDebCashless_Card  TransactionsDeb_PaymentOrder  Sex_F  Sex_M  \
# 0                     -0.662251                     -0.656065      0      1
# 1                     -0.662251                     -0.878077      0      1
# 2                     -0.290916                      0.231982      0      1
# 3                     -0.290916                      1.786065      1      0
# 4                     -0.662251                     -0.878077      1      0
#
#    Sale_CC  Sale_CC_probability
# 0        1             0.804298
# 1        0             0.239335
# 2        0             0.171947
# 3        0             0.271093
# 4        0             0.218232
#
# [5 rows x 29 columns]
#    Client       Age    Tenure  Count_CA  Count_SA  Count_MF  Count_OVD  \
# 0    1217 -0.201989  0.856457 -0.261832 -0.474815 -0.234571  -0.625833
# 1    1038 -0.684644 -0.013958 -0.261832 -0.474815 -0.234571  -0.625833
# 2    1219 -0.470131 -1.297450 -0.261832 -0.474815 -0.234571  -0.625833
# 3     461 -1.328183 -0.633575 -0.261832  1.611870 -0.234571  -0.625833
# 4    1048  1.245975 -0.530305 -0.261832 -0.474815 -0.234571   1.597871
#
#    Count_CC  Count_CL  ActBal_CA  ...  VolumeDebCashless_Card  \
# 0 -0.347571  -0.27232   3.089319  ...               -0.622229
# 1 -0.347571  -0.27232  -0.661882  ...               -0.622229
# 2 -0.347571  -0.27232   2.203540  ...               -0.526611
# 3 -0.347571  -0.27232  -0.673316  ...                1.034080
# 4 -0.347571  -0.27232   0.389233  ...               -0.622229
#
#    VolumeDeb_PaymentOrder  TransactionsDeb  TransactionsDebCash_Card  \
# 0                0.855818        -0.935019                 -0.706549
# 1               -0.717345        -0.996909                 -0.706549
# 2               -0.174840        -0.192340                 -0.037081
# 3                0.868325         0.117109                 -0.706549
# 4               -0.717345        -0.811239                 -0.371815
#
#    TransactionsDebCashless_Card  TransactionsDeb_PaymentOrder  Sex_F  Sex_M  \
# 0                     -0.675067                     -0.677040      0      1
# 1                     -0.675067                     -0.889569      0      1
# 2                     -0.301562                      0.173078      0      1
# 3                     -0.301562                      1.660784      1      0
# 4                     -0.675067                     -0.889569      1      0
#
#    Sale_CL  Sale_CL_probability
# 0        1             0.636685
# 1        0             0.210278
# 2        1             0.665703
# 3        1             0.895381
# 4        0             0.305996
#
# [5 rows x 29 columns]
#    Client       Age    Tenure  Count_CA  Count_SA  Count_MF  Count_OVD  \
# 0    1217 -0.151879  0.847268 -0.276266 -0.478657  -0.16359  -0.621202
# 1    1038 -0.639644 -0.041540 -0.276266 -0.478657  -0.16359  -0.621202
# 2    1219 -0.422860 -1.352156 -0.276266 -0.478657  -0.16359  -0.621202
# 3     461 -1.289998 -0.674251 -0.276266  1.470995  -0.16359  -0.621202
# 4    1048  1.311416 -0.568799 -0.276266 -0.478657  -0.16359   1.609782
#
#    Count_CC  Count_CL  ActBal_CA  ...  VolumeDebCashless_Card  \
# 0 -0.347571 -0.299283   3.274917  ...               -0.587701
# 1 -0.347571 -0.299283  -0.641290  ...               -0.587701
# 2 -0.347571 -0.299283   2.350175  ...               -0.489036
# 3 -0.347571 -0.299283  -0.653226  ...                1.121390
# 4 -0.347571 -0.299283   0.456062  ...               -0.587701
#
#    VolumeDeb_PaymentOrder  TransactionsDeb  TransactionsDebCash_Card  \
# 0                0.906674        -0.980229                 -0.702096
# 1               -0.727652        -1.046051                 -0.702096
# 2               -0.164055        -0.190370                 -0.064868
# 3                0.919666         0.138738                 -0.702096
# 4               -0.727652        -0.848586                 -0.383482
#
#    TransactionsDebCashless_Card  TransactionsDeb_PaymentOrder  Sex_F  Sex_M  \
# 0                     -0.663151                     -0.679950      0      1
# 1                     -0.663151                     -0.896858      0      1
# 2                     -0.266685                      0.187684      0      1
# 3                     -0.266685                      1.706044      1      0
# 4                     -0.663151                     -0.896858      1      0
#
#    Sale_MF  Sale_MF_probability
# 0        0             0.307690
# 1        1             0.790062
# 2        0             0.434391
# 3        0             0.488026
# 4        1             0.564904
#
# [5 rows x 29 columns]

# %%
Revenue = Revenue[['Client','Predicted_revenue']]
Propensity_CC = Propensity_CC[['Client','Sale_CC','Sale_CC_probability']]
Propensity_CL = Propensity_CL[['Client','Sale_CL','Sale_CL_probability']]
Propensity_MF = Propensity_MF[['Client','Sale_MF','Sale_MF_probability']]

# %%
dfs = [Revenue,Propensity_CC,Propensity_CL,Propensity_MF]
Client_predictions = reduce(lambda df1, df2 : pd.merge(df1,df2, on='Client', how='inner'), dfs)
Client_predictions.head()
# Out:
#    Client  Predicted_revenue  Sale_CC  Sale_CC_probability  Sale_CL  \
# 0    1217          11.283205        1             0.804298        1
# 1    1038          11.667446        0             0.239335        0
# 2    1219          11.169191        0             0.171947        1
# 3     461          12.039372        0             0.271093        1
# 4    1048          12.568632        0             0.218232        0
#
#    Sale_CL_probability  Sale_MF  Sale_MF_probability
# 0             0.636685        0             0.307690
# 1             0.210278        1             0.790062
# 2             0.665703        0             0.434391
# 3             0.895381        0             0.488026
# 4             0.305996        1             0.564904

# %%
Client_predictions['Highest_Propensity_probability'] = Client_predictions['Predicted_max_Revenue'] = Client_predictions[['Sale_CC_probability','Sale_CL_probability','Sale_MF_probability']].max(axis=1)
Client_predictions['Highest_Propensity_product'] = Client_predictions['Predicted_max_Revenue'] = Client_predictions[['Sale_CC_probability','Sale_CL_probability','Sale_MF_probability']].idxmax(axis=1)

# %%
Client_predictions['Highest_Propensity_product'] = Client_predictions['Highest_Propensity_product'].str.extract(r'Sale_(\w+)_')

# %%
Client_predictions['Predicted_max_Revenue'] = Client_predictions['Highest_Propensity_probability']*Client_predictions['Predicted_revenue']

# %%
Client_predictions.head()
# Out:
#    Client  Predicted_revenue  Sale_CC  Sale_CC_probability  Sale_CL  \
# 0    1217          11.283205        1             0.804298        1
# 1    1038          11.667446        0             0.239335        0
# 2    1219          11.169191        0             0.171947        1
# 3     461          12.039372        0             0.271093        1
# 4    1048          12.568632        0             0.218232        0
#
#    Sale_CL_probability  Sale_MF  Sale_MF_probability  \
# 0             0.636685        0             0.307690
# 1             0.210278        1             0.790062
# 2             0.665703        0             0.434391
# 3             0.895381        0             0.488026
# 4             0.305996        1             0.564904
#
#    Highest_Propensity_probability  Predicted_max_Revenue  \
# 0                        0.804298               9.075057
# 1                        0.790062               9.218001
# 2                        0.665703               7.435363
# 3                        0.895381              10.779823
# 4                        0.564904               7.100065
#
#   Highest_Propensity_product
# 0                         CC
# 1                         MF
# 2                         CL
# 3                         CL
# 4                         MF

# %%
Client_predictions.sort_values(by=['Predicted_max_Revenue'],ascending=False,inplace=True)

# %%
top_100_clients = Client_predictions.head(100)

# %%
Client_predictions.to_csv(results_folder_path+'Maximum_predicted_revenue_per_client.csv')

# %%
top_100_clients.to_csv(results_folder_path+'Top_100_clients.csv')

# %%
def main():
    print("Selecting top 100 clients")
if __name__ == "__main__":
    main()
# Out:
# Selecting top 100 clients

# %%
pip show pandas
# Out:
# Name: pandasNote: you may need to restart the kernel to use updated packages.
#
# Version: 1.5.3
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: The Pandas Development Team
# Author-email: pandas-dev@python.org
# License: BSD-3-Clause
# Location: c:\users\vivek.choudhary\appdata\local\anaconda3\lib\site-packages
# Requires: numpy, python-dateutil, pytz
# Required-by: datashader, holoviews, hvplot, seaborn, statsmodels, xarray
